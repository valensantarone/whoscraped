# %%
from whoscraped import functions

# %%
import LanusStats

# %%
url = 'https://www.whoscored.com/Matches/1803673/Live/International-UEFA-Nations-League-B-2024-2025-England-Finland'

# %%
functions.get_match_passes(url)
# Out:
#       minute  second        half  teamId  playerId              playerName  \
# 0          0       0   FirstHalf     422    255618             Glen Kamara
# 1          0       4   FirstHalf     422     64846          Lukás Hrádecky
# 2          0       6   FirstHalf     422    101113             Jere Uronen
# 3          0       9   FirstHalf     422     64846          Lukás Hrádecky
# 4          0      15   FirstHalf     345    318871  Trent Alexander-Arnold
# ...      ...     ...         ...     ...       ...                     ...
# 1080      94      39  SecondHalf     345    113069           Jack Grealish
# 1081      94      45  SecondHalf     345    332325             Declan Rice
# 1082      94      48  SecondHalf     345    338497             Angel Gomes
# 1083      94      54  SecondHalf     345    374631              Marc Guéhi
# 1084      94      55  SecondHalf     345    338497             Angel Gomes
#
#          x     y  endX   endY       outcome  isTouch
# ...
